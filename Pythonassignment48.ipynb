# %% [markdown]
# #Q1. Write a python program to calculate the length of a string

# %%
S=input ("Enter the string")
# Out:
# Enter the string Today is the first day of new year

# %%
print(S)
# Out:
#  Today is the first day of new year

# %% [markdown]
# #length of the string

# %%
L1=len(S)

# %%
print ("length of the string:",L1)
# Out:
# length of the string: 35

# %% [markdown]
# #Q2. Python program to calculate the square root.

# %%
import math

# %%
print("The square root of 16 is",math sqrt(16)) #pass the decimal number
# Out:
#   File "<ipython-input-28-126860e1d181>", line 1
#     print("The square root of 16 is",math sqrt(16)) #pass the decimal number
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# #Q3.Write a Python program to convert temperature in Celcius to temperature in Fahrenheit.

# %%
celsius=30

# %%
Fahrenheit=celsius*9/5+32

# %%
print (Fahrenheit)
# Out:
# 86.0

# %% [markdown]
# #Q4.Write a data type needed for given data.

# %%
num=10

# %%
type(10)
# Out:
# int

# %%
num1=4.5

# %%
type(num1)
# Out:
# float

# %%
num2=2+6j

# %%
type(num2)
# Out:
# complex
